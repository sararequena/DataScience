# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as stats
import math

# %%
df_2015 = pd.read_csv(r'C:\Users\SaraR\Desktop\Máster\Data Science & Advanced Analytics\Trabajo en grupo (python)\2015.csv')
df_2016 = pd.read_csv(r'C:\Users\SaraR\Desktop\Máster\Data Science & Advanced Analytics\Trabajo en grupo (python)\2016.csv')
df_2017 = pd.read_csv(r'C:\Users\SaraR\Desktop\Máster\Data Science & Advanced Analytics\Trabajo en grupo (python)\2017.csv')
df_2018 = pd.read_csv(r'C:\Users\SaraR\Desktop\Máster\Data Science & Advanced Analytics\Trabajo en grupo (python)\2018.csv')
df_2019 = pd.read_csv(r'C:\Users\SaraR\Desktop\Máster\Data Science & Advanced Analytics\Trabajo en grupo (python)\2019.csv')

# %%
df_2015["Year"] = "2015"
df_2016["Year"] = "2016"
df_2017["Year"] = "2017"
df_2018["Year"] = "2018"
df_2019["Year"] = "2019"

# %%
df_2017.rename(columns={'Happiness.Rank': 'Happiness Rank', 'Happiness.Score': 'Happiness Score', 'Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 'Health..Life.Expectancy.': 'Health (Life Expectancy)',
                        'Trust..Government.Corruption.': 'Trust (Government Corruption)', 'Dystopia.Residual': 'Dystopia Residual'}, inplace=True)
print(df_2017)
# Out:
#                       Country  Happiness Rank  Happiness Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df_2018.rename(columns={'Overall rank': 'Happiness Rank', 'Country or region': 'Country', 'Score': 'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support': 'Family', 'Healthy life expectancy': 'Health (Life Expectancy)',
                       'Freedom to make life choices': 'Freedom', 'Perceptions of corruption': 'Trust (Government Corruption)'}, inplace=True)
print(df_2018)
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.305   1.592                     0.874    0.681
# ...

# %%
df_2019.rename(columns={'Overall rank': 'Happiness Rank', 'Country or region': 'Country', 'Score': 'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support': 'Family', 'Healthy life expectancy': 'Health (Life Expectancy)',
                       'Freedom to make life choices': 'Freedom', 'Perceptions of corruption': 'Trust (Government Corruption)'}, inplace=True)
print(df_2019)
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.340   1.587                     0.986    0.596
# ...

# %%
dataframes = [df_2015, df_2016, df_2017, df_2018, df_2019]
result = pd.concat(dataframes, sort='False', ignore_index='True')
result
# Out:
#                       Country  Dystopia Residual  Economy (GDP per Capita)  \
# 0                 Switzerland            2.51738                   1.39651
# 1                     Iceland            2.70201                   1.30232
# 2                     Denmark            2.49204                   1.32548
# 3                      Norway            2.46531                   1.45900
# 4                      Canada            2.45176                   1.32629
# ..                        ...                ...                       ...
# 777                    Rwanda                NaN                   0.35900
# 778                  Tanzania                NaN                   0.47600
# 779               Afghanistan                NaN                   0.35000
# 780  Central African Republic                NaN                   0.02600
# 781               South Sudan                NaN                   0.30600
#
# ...

# %%
df_2019.head(10)
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
# 5               6  Switzerland            7.480                     1.452
# 6               7       Sweden            7.343                     1.387
# 7               8  New Zealand            7.307                     1.303
# 8               9       Canada            7.278                     1.365
# 9              10      Austria            7.246                     1.376
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.587                     0.986    0.596       0.153
# ...
